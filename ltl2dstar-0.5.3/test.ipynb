# %%
from graphviz import Source
import pydot

# %%
graph = pydot.graph_from_dot_file("my.dot")
graph = graph.pop()
graph.write_pdf("my.pdf")

# %%
with open("my.dot", 'r') as file23:
    text = file23.read()
Source(text)

# %%
import networkx as nx
G = nx.nx_agraph.read_dot("my.dot")

# %%
G["0"]["0"]
# Out:
# AtlasView({0: {'label': u' !a&!b&!c'}, 1: {'label': u' !a&b&!c'}})

# %%
import os
ltl = "[]<>a && []<>b && []!c"
with open("my.ltl", "w") as ltlfile:
    ltlfile.write(ltl)

# %%
os.system("ltlfilt -l -F \"my.ltl\" --output=\"my.ltl\" ")
os.system("./ltl2dstar --ltl2nba=spin:ltl2ba --stutter=no --output-format=dot my.ltl my.dot")
# Out:
# 0
